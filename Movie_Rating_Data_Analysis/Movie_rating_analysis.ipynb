# %% [markdown]
# ### Movie Rating Analysis  (Advanced Visualization)

# %%
import pandas as pd
import os

# %%
os.getcwd() # To get the working directory
# Out:
# 'c:\\Users\\haris\\Desktop\\vs_code\\Advanced_Data_Visualization'

# %%
movies = pd.read_csv(r'C:\Users\haris\Desktop\vs_code\Advanced_Data_Visualization\Movie_Rating_Data_Analysis\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
movies.head() #Removed spaces & % removed noise characters
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()      #Here Year must be an integer but it displayed as a float number
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe() #Here Year got changed into categorical data
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
#working with joint plots

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating')
# Audience rating is more dominant then critics rating
# Based on this we find out as most people are most liklihood to watch audience rating & less likely to wathc critics rating

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='hex')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='kde')

# %%
dist1 = sns.distplot(movies.AudienceRating)

# %%
sns.set_style('dark')

# %%
dist2 = sns.distplot(movies.AudienceRating, bins = 15)

# %%
sns.set_style('darkgrid')
hist1 = plt.hist(movies.AudienceRating, bins=15)

# %%
sns.set_style('white') #normal distribution & called as bell curve or Gaussian distribution curve 
hist2 = plt.hist(movies.AudienceRating, bins=20)

# %%
hist3 = plt.hist(movies.CriticRating, bins=20) #uniform distribution

# %%
plt.hist(movies.BudgetMillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 20,label='Action_Movies')
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 20,label='Thriller_Movies')
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 20,label='Drama_Movies')
plt.legend()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,
          movies[movies.Genre == 'Drama'].BudgetMillions, 
          movies[movies.Genre == 'Thriller'].BudgetMillions, 
          movies[movies.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
# Out:
# (array([[  7.,  22.,  27.,  16.,   8.,  16.,   9.,   5.,   7.,   6.,  12.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 32.,  62.,  45.,  24.,  14.,  18.,  10.,   5.,   7.,   6.,  13.,
#            2.,   3.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 34.,  73.,  52.,  26.,  18.,  20.,  14.,   6.,   8.,   6.,  14.,
#            2.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.],
#         [ 64., 127.,  88.,  44.,  32.,  34.,  18.,   7.,   8.,   6.,  14.,
#            3.,   4.,   8.,   1.,   2.,   1.,   1.,   0.,   1.]]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.,
#         165., 180., 195., 210., 225., 240., 255., 270., 285., 300.]),
#  <a list of 4 BarContainer objects>)

# %%
# if we have 100 categories you cannot copy & paste all the things then we have for loops

for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False)

# %%
vis2 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre')

# %%
sns.set_style('dark')
vis3 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=True, hue = 'Genre')

# %%
k1 = sns.kdeplot(movies.AudienceRating)

# %%
k1 = sns.kdeplot(movies.CriticRating)

# %%
k1 = sns.kdeplot(data=movies,x=movies.CriticRating,y=movies.AudienceRating)
# Kernal Density Estimate plot ( KDE PLOT) 
# visulize audience rating & critics rating . using scatterplot
# center point is kernal this is calld KDE & instead of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k1 = sns.kdeplot(data=movies,x=movies.CriticRating,y=movies.AudienceRating,shade = True,shade_lowest=False,cmap='Greens')

# %%
k1 = sns.kdeplot(x=movies.CriticRating,y=movies.AudienceRating,shade = True,shade_lowest=False,cmap='Reds_r')

# %%
sns.set_style('white')
k3 = sns.kdeplot(data=movies,x=movies.BudgetMillions,y=movies.AudienceRating,shade_lowest=False,cmap='Blues_r')

# %%
k4 = sns.kdeplot(data=movies,x=movies.BudgetMillions,y=movies.CriticRating,shade_lowest=False,cmap='Blues_r')

# %%
#subplots
fig, ax = plt.subplots(1,2, figsize =(12,6))

# %%
fig, axes = plt.subplots(1,2, figsize =(12,6))
k1 = sns.kdeplot(data=movies,x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[0])
k2 = sns.kdeplot(data=movies,x=movies.BudgetMillions,y=movies.CriticRating,ax=axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
#Box plots - 
w = sns.boxplot(data=movies, x='Genre', y = 'CriticRating',hue='Genre')

# %%
#violin plot
v = sns.violinplot(data=movies, x='Genre', y = 'CriticRating')

# %%
v1 = sns.violinplot(data=movies, x='Genre', y = 'CriticRating',hue='Genre')

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating',hue='Year')

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Comedy'], x='Year', y = 'CriticRating',hue='Year',legend=None)

# %%
z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %%
# Createing a Facet grid

# %%
f1 =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
f2 =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
f2 = f2.map(plt.scatter, 'CriticRating', 'AudienceRating' ) #scatterplots are mapped in facetgrid

# %%
sns.set_style('dark')
f2 =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
f2 = f2.map(plt.scatter, 'CriticRating', 'AudienceRating' )

# %%
f3 =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
f3 = f3.map(plt.hist, 'BudgetMillions')

# %%
f3 =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='Red')
f3 = f3.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws ) #kws is used to highlight the size and outer boarder of data

# %%
sns.set_style('darkgrid')
fig, axes = plt.subplots (2,2, figsize = (13,15))

k1 = sns.kdeplot(data=movies,x=movies.BudgetMillions,y=movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(data=movies,x=movies.BudgetMillions,y=movies.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,200))
k2.set(xlim=(-20,200))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0],hue='Year')

k4 = sns.kdeplot(data=movies,x=movies.CriticRating,y=movies.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])


plt.show()

# %%
sns.set_style('white',{'axes.facecolor':"Black"})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(data=movies,x=movies.BudgetMillions,y=movies.AudienceRating,cmap = 'cool',ax = axes[0,0])

#plot [0,1]
w= sns.boxplot(data=movies, x='Genre', y = 'CriticRating',hue='Genre',ax=axes[0,1])


#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0],hue='Year')

#plot[1,1]
k4 = sns.kdeplot(data=movies,x=movies.CriticRating,y=movies.AudienceRating, shade = True,shade_lowest=False,cmap='Blues_r',ax=axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
